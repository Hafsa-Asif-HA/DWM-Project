# %% [markdown]
# # import libraries

# %%
import numpy as np 
import pandas as pd # for working with dataframes
import seaborn as sns # for data visualization 

from matplotlib import pyplot as plt # for plotting
# %matplotlib inline
sns.set_style("whitegrid")

import warnings # http://blog.johnmuellerbooks.com/2015/11/30/warnings-in-python-and-anaconda/
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading and Viewing Dataset

# %% [markdown]
# # Fetching from Kaggle API

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
dataset1 = 'https://www.kaggle.com/datasets/zaheenhamidani/ultimate-spotify-tracks-db'

# %%
od.download(dataset1)

# %%
import os

# %%
data_dir1 = '.\\ultimate-spotify-tracks-db'

# %%
os.listdir(data_dir1)

# %%
data_features = pd.read_csv('SpotifyFeatures.csv')
data_features

# %%
dataset2 = 'https://www.kaggle.com/datasets/lehaknarnauli/spotify-datasets'

# %%
od.download(dataset2)
# Out:
# Skipping, found downloaded files in ".\spotify-datasets" (use force=True to force download)

# %%
data_dir2 = '.\\spotify-datasets'

# %%
os.listdir(data_dir2)
# Out:
# ['.ipynb_checkpoints']

# %%
df_track = pd.read_csv('tracks.csv')
df_track
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
data_artists = pd.read_csv('artists.csv')
data_artists
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %% [markdown]
# # check null values

# %%
df_track.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
data_features.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
data_artists.isnull().sum()
# Out:
# id             0
# followers     13
# genres         0
# name           0
# popularity     0
# dtype: int64

# %% [markdown]
# # Data Shape

# %%
df_track.shape
# ~600,000 observations and 20 features.
# Out:
# (586672, 20)

# %%
data_artists.shape
# ~1048575 artist based on 5 features.
# Out:
# (1104349, 5)

# %%
data_features.shape
# 232725 observations and 18 features.
# Out:
# (232725, 18)

# %% [markdown]
# # Check for Data types

# %%
df_track.info
# Out:
# <bound method DataFrame.info of                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
data_artists.info
# Out:
# <bound method DataFrame.info of                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %%
data_features.info
# Out:
# <bound method DataFrame.info of         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
# ...

# %% [markdown]
# # check for duplicate values

# %%
data_features.duplicated().sum()
# Out:
# 0

# %%
data_artists.duplicated().sum()
# Out:
# 0

# %%
df_track.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Datetime Data

# %%
import datetime

# %%
categorical_df = df_track.select_dtypes(include = 'object')

categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            586672 non-null  object
#  1   name          586601 non-null  object
#  2   artists       586672 non-null  object
#  3   id_artists    586672 non-null  object
#  4   release_date  586672 non-null  object
# dtypes: object(5)
# memory usage: 22.4+ MB

# %%
df_track.release_date = pd.to_datetime(df_track.release_date)

# %%
df_track.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %% [markdown]
# # Date and Time

# %%
#Find the first date in the dataset
df_track.release_date.min()
# Out:
# Timestamp('1900-01-01 00:00:00')

# %%
#Find the last date in the dataset
df_track.release_date.max()
# Out:
# Timestamp('2021-04-16 00:00:00')

# %%
df_track.hist(bins = 20, color = 'orange', figsize = (20, 14))
# Out:
# array([[<AxesSubplot:title={'center':'popularity'}>,
#         <AxesSubplot:title={'center':'duration_ms'}>,
#         <AxesSubplot:title={'center':'explicit'}>,
#         <AxesSubplot:title={'center':'danceability'}>],
#        [<AxesSubplot:title={'center':'energy'}>,
#         <AxesSubplot:title={'center':'key'}>,
#         <AxesSubplot:title={'center':'loudness'}>,
#         <AxesSubplot:title={'center':'mode'}>],
#        [<AxesSubplot:title={'center':'speechiness'}>,
#         <AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'instrumentalness'}>,
#         <AxesSubplot:title={'center':'liveness'}>],
#        [<AxesSubplot:title={'center':'valence'}>,
#         <AxesSubplot:title={'center':'tempo'}>,
#         <AxesSubplot:title={'center':'time_signature'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_features.hist(bins = 20, color = 'blue', figsize = (20, 14))
# Out:
# array([[<AxesSubplot:title={'center':'popularity'}>,
#         <AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'danceability'}>],
#        [<AxesSubplot:title={'center':'duration_ms'}>,
#         <AxesSubplot:title={'center':'energy'}>,
#         <AxesSubplot:title={'center':'instrumentalness'}>],
#        [<AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'loudness'}>,
#         <AxesSubplot:title={'center':'speechiness'}>],
#        [<AxesSubplot:title={'center':'tempo'}>,
#         <AxesSubplot:title={'center':'valence'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_artists.hist(bins = 20, color = 'red', figsize = (15, 5))
# Out:
# array([[<AxesSubplot:title={'center':'followers'}>,
#         <AxesSubplot:title={'center':'popularity'}>]], dtype=object)

# %% [markdown]
# # most popular categories

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_track.release_date = pd.to_datetime(df_track.release_date)

# %%
#Find the number of songs per year
df_track["year"] = df_track["release_date"].dt.year
sns.displot(df_track["year"], discrete = True, aspect = 2, height = 7, kind = "hist", kde = True, color = 'green').set(title="Number of song per year")

# %%
total_dr=df_track["duration"]
fig,ax=plt.subplots()
fig=sns.barplot(x=df_track["year"],y=total_dr,ax=ax,errwidth=False).set(title="Year vs Duration")

# %%
sns.set_style(style="whitegrid")
fig_dims=(10,5)
fig,ax=plt.subplots(figsize=fig_dims)
fig=sns.lineplot(x=df_track["year"],y=total_dr,ax=ax).set(title="year vs duration")
plt.xticks(rotation=60)
# Out:
# (array([1880., 1900., 1920., 1940., 1960., 1980., 2000., 2020., 2040.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # check for specific row in data

# %%
df_track["artists"].iloc[18]
# Out:
# "['Victor Boucher']"

# %% [markdown]
# # convert ms into seconds

# %%
df_track["duration"]= df_track["duration_ms"].apply(lambda x: round(x/1000))
df_track.drop("duration_ms", inplace=True, axis=1)
df_track.duration.head()
# Out:
# 0    127
# 1     98
# 2    182
# 3    177
# 4    163
# Name: duration, dtype: int64

# %% [markdown]
# # drop

# %%
corr_df=df_track.drop( ["key", "mode", "explicit"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df, annot=True, fmt=".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1, linecolor = "Black")
heatmap.set_title("Correlation HeatMap Between Variable")
heatmap.set_xticklabels (heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'year'),
#  Text(12.5, 0, 'duration')]

# %% [markdown]
# # sampling

# %%
sample_df = df_track.sample(int(0.004*len (df_track)))
print (len (sample_df))
# Out:
# 2346

# %% [markdown]
# # Most popular artist on spotify

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

plt.figure(figsize = (20, 14))

def visualize_word_counts(counts):
    wc = WordCloud(max_font_size=130, min_font_size=25, colormap='tab20', background_color='white', prefer_horizontal=.95, width=2100, height=700, random_state=0)
    cloud = wc.generate_from_frequencies(counts)
    plt.figure(figsize=(18,15))
    plt.imshow(cloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
lead_artists = df_track['artists'].value_counts().head(20)

lead_artists
# Out:
# ['Die drei ???']                              3856
# ['TKKG Retro-Archiv']                         2006
# ['Benjamin Blümchen']                         1503
# ['Bibi Blocksberg']                           1472
# ['Lata Mangeshkar']                           1373
# ['Bibi und Tina']                              927
# ['Tintin', 'Tomas Bolme', 'Bert-Åke Varg']     905
# ['Francisco Canaro']                           891
# ['Ella Fitzgerald']                            870
# ['Tadeusz Dolega Mostowicz']                   838
# ['Fünf Freunde']                               812
# ['Mohammed Rafi']                              787
# ['Queen']                                      777
# ['Frank Sinatra']                              680
# ['Elvis Presley']                              680
# ['The Rolling Stones']                         654
# ['Die Originale']                              638
# ['Billie Holiday']                             609
# ...

# %%
fig, ax = plt.subplots(figsize = (12, 10))

ax = sns.barplot(x = lead_artists.values, y = lead_artists.index, palette = 'rocket_r', orient = 'h', edgecolor = 'black', ax = ax)

ax.set_xlabel('Sum of Songs', c ='r', fontsize = 12, weight = 'bold')
ax.set_ylabel('Artists', c = 'r', fontsize = 12, weight = 'bold')
ax.set_title('20 Most Popular Artists in Dataset', c = 'r', fontsize = 14, weight = 'bold')

plt.show()

# %% [markdown]
# # most popular song on spotify

# %%
most_popular_song = df_track.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)

most_popular_song.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  explicit                                         artists  \
# 93802         100         1    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# ...

# %%
lead_songs = most_popular_song[['name', 'popularity']].head(20)

lead_songs
# Out:
#                                                     name  popularity
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# 92810                                    Save Your Tears          97
# 92811                                          telepatía          97
# 92813                                    Blinding Lights          96
# 93805                                Leave The Door Open          96
# 92814                                       The Business          95
# 91866                                            Streets          94
# 92816                             Heartbreak Anniversary          94
# 92817                                        WITHOUT YOU          94
# 92819                                            Bandido          94
# 93807  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...          94
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 10))

ax = sns.barplot(x = lead_songs.popularity, y = lead_songs.name, color = 'lightgreen', orient = 'h', edgecolor = 'black', ax = ax)

ax.set_xlabel('Popularity', c ='red', fontsize = 12, weight = 'bold')
ax.set_ylabel('Songs', c = 'red', fontsize = 12, weight = 'bold')
ax.set_title('20 Most Popular Songs in Dataset', c = 'red', fontsize = 14, weight = 'bold')

plt.show()

# %% [markdown]
# # least popular song on spotify

# %%
least_popular_song = df_track.sort_values('popularity', ascending = True).head(10)
least_popular_song
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 4))

ax = sns.barplot(x = least_popular_song.popularity, y = lead_songs.name, color = 'lightgreen', orient = 'h', edgecolor = 'black', ax = ax)

ax.set_xlabel('Popularity', c ='red', fontsize = 12, weight = 'bold')
ax.set_ylabel('Songs', c = 'red', fontsize = 12, weight = 'bold')
ax.set_title('10 Least Popular Songs in Dataset', c = 'red', fontsize = 14, weight = 'bold')

plt.show()

# %% [markdown]
# # Regression Line

# %%
plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="Loudness vs Energy correlation")
#very high positive corr
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy correlation')]

# %%
plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="c").set(title="popularity vs accoustic corr")
#inversely proportional
# Out:
# [Text(0.5, 1.0, 'popularity vs accoustic corr')]

# %% [markdown]
# # Spotify Feature

# %%
plt.title("Duration of song in diff geners")
sns.color_palette("rocket",as_cmap=True)
sns.barplot(y=data_features["genre"],x=data_features["duration_ms"],data=data_features)
plt.xlabel("Duration in milli second")
plt.ylabel("Geners")
# Out:
# Text(0, 0.5, 'Geners')

# %% [markdown]
# # Most popular genre

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,5))
famous=data_features.sort_values("popularity",ascending=False).head(10)
sns.barplot(y="genre",x="popularity",data=famous).set(title="top 10 genres by popularity")
# Out:
# [Text(0.5, 1.0, 'top 10 genres by popularity')]

# %%
sns.distplot(data_features['popularity']).set_title('Popularity Distribution')
# Out:
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
sns.barplot(x = 'time_signature', y = 'popularity', data = data_features)
plt.title('Popularity Based on Time Signature')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 'key', y = 'popularity', data = data_features)
plt.title('Popularity Based on Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key')

# %%
sns.barplot(x = 'mode', y = 'popularity', data = data_features)
plt.title('Popularity Based on Mode')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode')

# %%
#Since key and mode are related (there can be A major or A minor), we combine those two features in another barplot using "hue".
sns.barplot(x = 'mode', y = 'popularity', hue = 'key', data = data_features)
plt.title('Popularity Based on Mode and Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode and Key')

# %%
popular_above_50 = data_features[data_features.popularity > 50]
sns.distplot(popular_above_50['acousticness'])
plt.title('Acoustiness for Songs with More than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Acoustiness for Songs with More than 50 Popularity')

# %%
popular_below_50 = data_features[data_features.popularity < 50]
sns.distplot(popular_below_50['acousticness'])
plt.title('Acoustiness for Songs with Less than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Acoustiness for Songs with Less than 50 Popularity')

# %%
sns.distplot(popular_above_50['loudness'])
plt.title('Loudness for Songs with More than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Loudness for Songs with More than 50 Popularity')

# %%
popular_below_50 = data_features[data_features.popularity < 50]
sns.distplot(popular_below_50['loudness'])
plt.title('Loudness for Songs with Less than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Loudness for Songs with Less than 50 Popularity')
